# %% [markdown]
# <a href="https://colab.research.google.com/github/mr-marius/Machine-Learning---DIO-/blob/main/02_reducao_dimensionalidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# Leitura da imagem
img = cv2.imread('/content/images/gato.png')
if img is None:
    print("Erro ao carregar a imagem. Verifique o caminho.")
    exit()

# %%
# Conversão para escala de cinza
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Aplicação de desfoque (blur)
suave = cv2.GaussianBlur(img, (7, 7), 0)

# %%
# Binarização simples e invertida
(T, bin) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY)
(T, binI) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY_INV)

# %%
# Combinação das imagens para exibição
resultado = np.vstack([
    np.hstack([suave, bin]),
    np.hstack([binI, cv2.bitwise_and(img, img, mask=binI)])
])

# %%
# Exibição do resultado using cv2_imshow instead of cv2.imshow
cv2_imshow(resultado)
# Out:
# <PIL.Image.Image image mode=L size=7774x10884>
